# %% [markdown]
# # Combined Datasets — 3 Representation Comparative Benchmark
#
# Evaluates all 3 representations (Spectrogram, Projections, Point Set) side-by-side on **Combined Datasets**.

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

sns.set_theme(style="whitegrid")

preproc_dir = Path("datasets/preprocessed")
if not preproc_dir.exists(): preproc_dir = Path("../datasets/preprocessed")
if not preproc_dir.exists(): preproc_dir = Path("../../datasets/preprocessed")

X1 = np.load(preproc_dir / "X_rep1_spectrogram_combined.npy")
X2 = np.load(preproc_dir / "X_rep2_projections_combined.npy")
X3 = np.load(preproc_dir / "X_rep3_pointset_combined.npy")
y = np.load(preproc_dir / "y_combined_clean_balanced.npy")

print(f"Loaded Rep 1: {X1.shape} | Rep 2: {X2.shape} | Rep 3: {X3.shape}")
print(f"Labels: {np.bincount(y.astype(int))}")

# %%
# Benchmark Results Summary Table
summary_data = [
    {"Representation": "Representation 1: Micro-Doppler Spectrogram", "Model": "ResNet-18 (Kinematic)", "Input Shape": str(X1.shape[1:])},
    {"Representation": "Representation 2: Orthogonal Projections", "Model": "ResNet-18 (Spatial)", "Input Shape": str(X2.shape[1:])},
    {"Representation": "Representation 3: Native 3D Point Set", "Model": "PointNet++ (Geometric)", "Input Shape": str(X3.shape[1:])}
]
df_summary = pd.DataFrame(summary_data)
display(df_summary)
